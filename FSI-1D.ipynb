# %% [markdown]
# #choose an example in the book
#
# 力学模型
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)
#
# 数学模型
#
# #structure dyanmics equation
#
# $$m{{{d^2}u} \over {d{t^2}}} + k{{du} \over {dx}} = \delta (x - {x_0})$$
#
# $${m_p}\ddot u + {k_p}u(t) = A(p(t) - {p_0})$$
#
# $$u = {u^0},\dot u(0) = 0$$
# #fluid equation
#
# #interaction equation
# #list the governing equation and the analytical solution
#
# #discretize them
#
# structure solver
# $${u^{n + 1}} = {u^n} + \Delta t{{\dot u}^n} + {{\Delta {t^2}} \over 4}({{\ddot u}^n} + {{\ddot u}^{n + 1}})$$
# $${{\dot u}^{n + 1}} = {{\dot u}^n} + {{\Delta t} \over 2}({{\ddot u}^n} + {{\ddot u}^{n + 1}})$$
# $${{\ddot u}^{n + 1}} = {4 \over {\Delta {t^2}}}\Delta u - {4 \over {\Delta t}}{{\dot u}^n} - {{\ddot u}^n}$$
#
# #algorithm
#
# #data structure
